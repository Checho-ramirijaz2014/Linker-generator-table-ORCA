# %% [markdown]
# ## Extraccion de los outputs

# %% [markdown]
# ##### Funciona con archivos que terminan en .out generados por ORCA
# ##### Por defecto solo va a seleccionar los datos que posean un wavelegth superior a 200 nm

# %%
import os
import pandas as pd
import numpy as np
import re
from IPython.display import HTML
pd.set_option.max_columns_width = None
pd.options.display.max_rows = None

# %%
minimo_espectro = float(input("escribe el minimo del espectro de la fortaleza del oscilador (ej: 0.01):"))
maximo_espectro = float(input("escribe el maximo del espectro de la fortaleza del oscilador (ej: 1):"))
path = "archivos" #modificar aca con el nombre de la carpetan que crearon dentro del directorio root, tiene que estar entre comillas
minimo_longitud_onda = 200
os.chdir("..")
os.chdir("root")
# Out:
# escribe el minimo del espectro de la fortaleza del oscilador (ej: 0.01):0.01
# escribe el maximo del espectro de la fortaleza del oscilador (ej: 1):1

# %%
#funciones necesarias para el programa. NO MODIFICAR
patron = r"au\s*([\d.]+)"
patron_transicion = r'\d+\.\d+'
patron_orbital = r'[-+]?\d*\.\d+|\d+'
def espacios_state(num):
    if len(str(num)) == 1:
        return  ' ' + str(num)
    elif len(str(num)) == 2:
        return str(num)

def string_transicion(num: int):
    if num > 0:
        return "+"+str(num)
    if num < 0:
        return "-"+str(abs(num))
    if num == 0:
        return ""

def convertir_transicion(string: str, homo: int, lumo: int):
    string = string.replace("a", "")
    string = string.split("-")
    diferencia_homo = int(string[0]) - homo
    diferencia_lumo = int(string[1]) - lumo
    diferencia_homo = string_transicion(diferencia_homo)
    diferencia_lumo = string_transicion(diferencia_lumo)
    return "H"+diferencia_homo+"→L"+diferencia_lumo

def encontrar_keys(dicc: dict):
    llave = []
    valor = None
    for key, value in dicc.items():
        if valor is not None and value != valor:
            llave.append(key)
        valor = value
    llave = int(llave[0])
    return llave

def log(mensaje: str):
        print("|" + (" "+mensaje+" ").center(50, "-") + "|")

# %%
#indica los archivos que se leeran en el path dado
def obtener_archivos_out(extension):
    file_list = []
    for archivo in os.listdir(os.path.join(os.getcwd())):
        if archivo.endswith(extension):
            file_list.append(archivo)
    return file_list

archivos = obtener_archivos_out('.out')

log("Lista de archivos out")
for filename in archivos:
    print(filename)

log(f"Numero total de archivos: {len(archivos)}")
# Out:
# |------------- Lista de archivos out --------------|
# td_m1.out
# |---------- Numero total de archivos: 1 -----------|

# %%
# %%time
#%%capture captured_output
for filename in archivos:
    tabla = pd.DataFrame(columns=["State", "E(eV)", "λ(nm)", "f", "Assignment", "MOs Transition", "cts (%)"])
    columnas = ["State", "Energy (cm-1)", "Wavelength (nm)", "fosc", "T2 (au**2)", "TX (au)", "TY (au)", "TZ (au)"]
    log(filename.split(".out")[0].split("td_")[1])
    df = pd.DataFrame(columns=columnas)
    with open(os.path.join(os.getcwd()) + "/" + filename, "rt") as file:
        for key, linea in enumerate(file):
            print(f"linea: {key}")
            if "ABSORPTION SPECTRUM VIA TRANSITION ELECTRIC DIPOLE MOMENTS" in linea:
                #print(f"Linea en donde estan los datos sobre el espectro de absorcion: {key+1}")
                while True:
                    datum = file.readline()
                    if datum.strip() == "":
                        df.drop(["T2 (au**2)", "TX (au)", "TY (au)", "TZ (au)"], axis=1, inplace=True)
                        df["State"] = df["State"].astype(np.uint8)
                        df["Wavelength (nm)"] = df["Wavelength (nm)"].astype(np.float16)
                        df[["Energy (cm-1)", "fosc"]] = df[["Energy (cm-1)", "fosc"]].astype(np.float32)
                        break
                    numeros = [numero for numero in datum.split()]
                    if not numeros[0].isnumeric():
                        continue
                    df.loc[len(df.index)] = numeros
                df = df.loc[(df["fosc"] >= minimo_espectro) & (df["fosc"] <= maximo_espectro) & (df["Wavelength (nm)"] >  minimo_longitud_onda)]
                df.reset_index(drop=True, inplace=True)
                break
        #calcular los estados
        file.seek(0)
        for key, line in enumerate(file):
            if "NO" in line and "OCC" in line and "E(Eh)" in line and "E(eV)" in line:
                orbitales = {}
                while True:
                    datum = file.readline()
                    if datum[0] == "-":
                        break
                    numeros = re.findall(patron_orbital, datum)
                    orbitales[numeros[0]] = numeros[1]
                lumo = encontrar_keys(orbitales)
                homo = lumo - 1

        #agrega los datos en una tabla
        file.seek(0)
        tabla[["State", "λ(nm)", "f"]] = df[["State", "Wavelength (nm)", "fosc"]]
        tabla["Assignment"] = "π→π*"
        tabla["Assignment"] = tabla["Assignment"].astype("category")
        for key, linea in enumerate(file):
            for x in range(len(df)):
                estado = df['State'].iloc[x]
                if str("STATE " + espacios_state(estado)) in linea:
                    energia = float(re.search(patron, linea).group(1))
                    tabla.loc[tabla.State == int(estado), "E(eV)"] = energia
                    estados = {}
                    while True:
                        datum = file.readline()
                        if datum.strip() == "":
                            transicion = max(estados, key=estados.get)
                            max_cts = estados[transicion]
                            tabla.loc[tabla.State == int(estado), "MOs Transition"] = convertir_transicion(transicion, homo, lumo)
                            tabla.loc[tabla.State == int(estado), "cts (%)"] = max_cts
                            break

                        estados[datum.split(":")[0].replace(' ', '').replace('>', '')] = float(re.search(patron_transicion, datum.split(":")[1]).group())
        tabla['λ(nm)'] = tabla['λ(nm)'].round(0).astype(int)
        tabla["E(eV)"] = tabla["E(eV)"].astype(float).round(2)
        tabla['f'] = tabla['f'].round(2)
        tabla['cts (%)'] = tabla['cts (%)'].astype(float).round(2) * 100
        tabla['cts (%)'] = tabla['cts (%)'].astype(int).map(lambda x: f"{x}%")
        tabla.drop(["State"], axis=1, inplace=True)
        tabla.set_index("E(eV)", inplace=True)
        tabla.columns.name = tabla.index.name
        tabla.index.name = None
        print(tabla)
log("PROCESO TERMINADO")
#%%writefile output.txt
#print(captured_output.stdout)
# Out:
# Streaming output truncated to the last 5000 lines.
# linea: 675894
# linea: 675895
# linea: 675896
# linea: 675897
# linea: 675898
# linea: 675899
# linea: 675900
# linea: 675901
# linea: 675902
# linea: 675903
# linea: 675904
# linea: 675905
# linea: 675906
# linea: 675907
# linea: 675908
# linea: 675909
# linea: 675910
# linea: 675911
# linea: 675912
# linea: 675913
# linea: 675914
# linea: 675915
# linea: 675916
# linea: 675917
# linea: 675918
# linea: 675919
# linea: 675920
# linea: 675921
# linea: 675922
# linea: 675923
# linea: 675924
# linea: 675925
# linea: 675926
# linea: 675927
# linea: 675928
# linea: 675929
# linea: 675930
# linea: 675931
# linea: 675932
# linea: 675933
# linea: 675934
# linea: 675935
# linea: 675936
# linea: 675937
# linea: 675938
# linea: 675939
# linea: 675940
# linea: 675941
# linea: 675942
# linea: 675943
# linea: 675944
# linea: 675945
# linea: 675946
# linea: 675947
# linea: 675948
# linea: 675949
# linea: 675950
# linea: 675951
# linea: 675952
# linea: 675953
# linea: 675954
# linea: 675955
# linea: 675956
# linea: 675957
# linea: 675958
# linea: 675959
# linea: 675960
# linea: 675961
# linea: 675962
# linea: 675963
# linea: 675964
# linea: 675965
# linea: 675966
# linea: 675967
# linea: 675968
# linea: 675969
# linea: 675970
# linea: 675971
# linea: 675972
# linea: 675973
# linea: 675974
# linea: 675975
# linea: 675976
# linea: 675977
# linea: 675978
# linea: 675979
# linea: 675980
# linea: 675981
# linea: 675982
# linea: 675983
# linea: 675984
# linea: 675985
# linea: 675986
# linea: 675987
# linea: 675988
# linea: 675989
# linea: 675990
# linea: 675991
# linea: 675992
# linea: 675993
# linea: 675994
# linea: 675995
# linea: 675996
# linea: 675997
# linea: 675998
# linea: 675999
# linea: 676000
# linea: 676001
# linea: 676002
# linea: 676003
# linea: 676004
# linea: 676005
# linea: 676006
# linea: 676007
# linea: 676008
# linea: 676009
# linea: 676010
# linea: 676011
# linea: 676012
# linea: 676013
# linea: 676014
# linea: 676015
# linea: 676016
# linea: 676017
# linea: 676018
# linea: 676019
# linea: 676020
# linea: 676021
# linea: 676022
# linea: 676023
# linea: 676024
# linea: 676025
# linea: 676026
# linea: 676027
# linea: 676028
# linea: 676029
# linea: 676030
# linea: 676031
# linea: 676032
# linea: 676033
# linea: 676034
# linea: 676035
# linea: 676036
# linea: 676037
# linea: 676038
# linea: 676039
# linea: 676040
# linea: 676041
# linea: 676042
# linea: 676043
# linea: 676044
# linea: 676045
# linea: 676046
# linea: 676047
# linea: 676048
# linea: 676049
# linea: 676050
# linea: 676051
# linea: 676052
# linea: 676053
# linea: 676054
# linea: 676055
# linea: 676056
# linea: 676057
# linea: 676058
# linea: 676059
# linea: 676060
# linea: 676061
# linea: 676062
# linea: 676063
# linea: 676064
# linea: 676065
# linea: 676066
# linea: 676067
# linea: 676068
# linea: 676069
# linea: 676070
# linea: 676071
# linea: 676072
# linea: 676073
# linea: 676074
# linea: 676075
# linea: 676076
# linea: 676077
# linea: 676078
# linea: 676079
# linea: 676080
# linea: 676081
# linea: 676082
# linea: 676083
# linea: 676084
# linea: 676085
# linea: 676086
# linea: 676087
# linea: 676088
# linea: 676089
# linea: 676090
# linea: 676091
# linea: 676092
# linea: 676093
# linea: 676094
# linea: 676095
# linea: 676096
# linea: 676097
# linea: 676098
# linea: 676099
# linea: 676100
# linea: 676101
# linea: 676102
# linea: 676103
# linea: 676104
# linea: 676105
# linea: 676106
# linea: 676107
# linea: 676108
# linea: 676109
# linea: 676110
# linea: 676111
# linea: 676112
# linea: 676113
# linea: 676114
# linea: 676115
# linea: 676116
# linea: 676117
# linea: 676118
# linea: 676119
# linea: 676120
# linea: 676121
# linea: 676122
# linea: 676123
# linea: 676124
# linea: 676125
# linea: 676126
# linea: 676127
# linea: 676128
# linea: 676129
# linea: 676130
# linea: 676131
# linea: 676132
# linea: 676133
# linea: 676134
# linea: 676135
# linea: 676136
# linea: 676137
# linea: 676138
# linea: 676139
# linea: 676140
# linea: 676141
# linea: 676142
# linea: 676143
# linea: 676144
# linea: 676145
# linea: 676146
# linea: 676147
# linea: 676148
# linea: 676149
# linea: 676150
# linea: 676151
# linea: 676152
# linea: 676153
# linea: 676154
# linea: 676155
# linea: 676156
# linea: 676157
# linea: 676158
# linea: 676159
# linea: 676160
# linea: 676161
# linea: 676162
# linea: 676163
# linea: 676164
# linea: 676165
# linea: 676166
# linea: 676167
# linea: 676168
# linea: 676169
# linea: 676170
# linea: 676171
# linea: 676172
# linea: 676173
# linea: 676174
# linea: 676175
# linea: 676176
# linea: 676177
# linea: 676178
# linea: 676179
# linea: 676180
# linea: 676181
# linea: 676182
# linea: 676183
# linea: 676184
# linea: 676185
# linea: 676186
# linea: 676187
# linea: 676188
# linea: 676189
# linea: 676190
# linea: 676191
# linea: 676192
# linea: 676193
# linea: 676194
# linea: 676195
# linea: 676196
# linea: 676197
# linea: 676198
# linea: 676199
# linea: 676200
# linea: 676201
# linea: 676202
# linea: 676203
# linea: 676204
# linea: 676205
# linea: 676206
# linea: 676207
# linea: 676208
# linea: 676209
# linea: 676210
# linea: 676211
# linea: 676212
# linea: 676213
# linea: 676214
# linea: 676215
# linea: 676216
# linea: 676217
# linea: 676218
# linea: 676219
# linea: 676220
# linea: 676221
# linea: 676222
# linea: 676223
# linea: 676224
# linea: 676225
# linea: 676226
# linea: 676227
# linea: 676228
# linea: 676229
# linea: 676230
# linea: 676231
# linea: 676232
# linea: 676233
# linea: 676234
# linea: 676235
# linea: 676236
# linea: 676237
# linea: 676238
# linea: 676239
# linea: 676240
# linea: 676241
# linea: 676242
# linea: 676243
# linea: 676244
# linea: 676245
# linea: 676246
# linea: 676247
# linea: 676248
# linea: 676249
# linea: 676250
# linea: 676251
# linea: 676252
# linea: 676253
# linea: 676254
# linea: 676255
# linea: 676256
# linea: 676257
# linea: 676258
# linea: 676259
# linea: 676260
# linea: 676261
# linea: 676262
# linea: 676263
# linea: 676264
# linea: 676265
# linea: 676266
# linea: 676267
# linea: 676268
# linea: 676269
# linea: 676270
# linea: 676271
# linea: 676272
# linea: 676273
# linea: 676274
# linea: 676275
# linea: 676276
# linea: 676277
# linea: 676278
# linea: 676279
# linea: 676280
# linea: 676281
# linea: 676282
# linea: 676283
# linea: 676284
# linea: 676285
# linea: 676286
# linea: 676287
# linea: 676288
# linea: 676289
# linea: 676290
# linea: 676291
# linea: 676292
# linea: 676293
# linea: 676294
# linea: 676295
# linea: 676296
# linea: 676297
# linea: 676298
# linea: 676299
# linea: 676300
# linea: 676301
# linea: 676302
# linea: 676303
# linea: 676304
# linea: 676305
# linea: 676306
# linea: 676307
# linea: 676308
# linea: 676309
# linea: 676310
# linea: 676311
# linea: 676312
# linea: 676313
# linea: 676314
# linea: 676315
# linea: 676316
# linea: 676317
# linea: 676318
# linea: 676319
# linea: 676320
# linea: 676321
# linea: 676322
# linea: 676323
# linea: 676324
# linea: 676325
# linea: 676326
# linea: 676327
# linea: 676328
# linea: 676329
# linea: 676330
# linea: 676331
# linea: 676332
# linea: 676333
# linea: 676334
# linea: 676335
# linea: 676336
# linea: 676337
# linea: 676338
# linea: 676339
# linea: 676340
# linea: 676341
# linea: 676342
# linea: 676343
# linea: 676344
# linea: 676345
# linea: 676346
# linea: 676347
# linea: 676348
# linea: 676349
# linea: 676350
# linea: 676351
# linea: 676352
# linea: 676353
# linea: 676354
# linea: 676355
# linea: 676356
# linea: 676357
# linea: 676358
# linea: 676359
# linea: 676360
# linea: 676361
# linea: 676362
# linea: 676363
# linea: 676364
# linea: 676365
# linea: 676366
# linea: 676367
# linea: 676368
# linea: 676369
# linea: 676370
# linea: 676371
# linea: 676372
# linea: 676373
# linea: 676374
# linea: 676375
# linea: 676376
# linea: 676377
# linea: 676378
# linea: 676379
# linea: 676380
# linea: 676381
# linea: 676382
# linea: 676383
# linea: 676384
# linea: 676385
# linea: 676386
# linea: 676387
# linea: 676388
# linea: 676389
# linea: 676390
# linea: 676391
# linea: 676392
# linea: 676393
# linea: 676394
# linea: 676395
# linea: 676396
# linea: 676397
# linea: 676398
# linea: 676399
# linea: 676400
# linea: 676401
# linea: 676402
# linea: 676403
# linea: 676404
# linea: 676405
# linea: 676406
# linea: 676407
# linea: 676408
# linea: 676409
# linea: 676410
# linea: 676411
# linea: 676412
# linea: 676413
# linea: 676414
# linea: 676415
# linea: 676416
# linea: 676417
# linea: 676418
# linea: 676419
# linea: 676420
# linea: 676421
# linea: 676422
# linea: 676423
# linea: 676424
# linea: 676425
# linea: 676426
# linea: 676427
# linea: 676428
# linea: 676429
# linea: 676430
# linea: 676431
# linea: 676432
# linea: 676433
# linea: 676434
# linea: 676435
# linea: 676436
# linea: 676437
# linea: 676438
# linea: 676439
# linea: 676440
# linea: 676441
# linea: 676442
# linea: 676443
# linea: 676444
# linea: 676445
# linea: 676446
# linea: 676447
# linea: 676448
# linea: 676449
# linea: 676450
# linea: 676451
# linea: 676452
# linea: 676453
# linea: 676454
# linea: 676455
# linea: 676456
# linea: 676457
# linea: 676458
# linea: 676459
# linea: 676460
# linea: 676461
# linea: 676462
# linea: 676463
# linea: 676464
# linea: 676465
# linea: 676466
# linea: 676467
# linea: 676468
# linea: 676469
# linea: 676470
# linea: 676471
# linea: 676472
# linea: 676473
# linea: 676474
# linea: 676475
# linea: 676476
# linea: 676477
# linea: 676478
# linea: 676479
# linea: 676480
# linea: 676481
# linea: 676482
# linea: 676483
# linea: 676484
# linea: 676485
# linea: 676486
# linea: 676487
# linea: 676488
# linea: 676489
# linea: 676490
# linea: 676491
# linea: 676492
# linea: 676493
# linea: 676494
# linea: 676495
# linea: 676496
# linea: 676497
# linea: 676498
# linea: 676499
# linea: 676500
# linea: 676501
# linea: 676502
# linea: 676503
# linea: 676504
# linea: 676505
# linea: 676506
# linea: 676507
# linea: 676508
# linea: 676509
# linea: 676510
# linea: 676511
# linea: 676512
# linea: 676513
# linea: 676514
# linea: 676515
# linea: 676516
# linea: 676517
# linea: 676518
# linea: 676519
# linea: 676520
# linea: 676521
# linea: 676522
# linea: 676523
# linea: 676524
# linea: 676525
# linea: 676526
# linea: 676527
# linea: 676528
# linea: 676529
# linea: 676530
# linea: 676531
# linea: 676532
# linea: 676533
# linea: 676534
# linea: 676535
# linea: 676536
# linea: 676537
# linea: 676538
# linea: 676539
# linea: 676540
# linea: 676541
# linea: 676542
# linea: 676543
# linea: 676544
# linea: 676545
# linea: 676546
# linea: 676547
# linea: 676548
# linea: 676549
# linea: 676550
# linea: 676551
# linea: 676552
# linea: 676553
# linea: 676554
# linea: 676555
# linea: 676556
# linea: 676557
# linea: 676558
# linea: 676559
# linea: 676560
# linea: 676561
# linea: 676562
# linea: 676563
# linea: 676564
# linea: 676565
# linea: 676566
# linea: 676567
# linea: 676568
# linea: 676569
# linea: 676570
# linea: 676571
# linea: 676572
# linea: 676573
# linea: 676574
# linea: 676575
# linea: 676576
# linea: 676577
# linea: 676578
# linea: 676579
# linea: 676580
# linea: 676581
# linea: 676582
# linea: 676583
# linea: 676584
# linea: 676585
# linea: 676586
# linea: 676587
# linea: 676588
# linea: 676589
# linea: 676590
# linea: 676591
# linea: 676592
# linea: 676593
# linea: 676594
# linea: 676595
# linea: 676596
# linea: 676597
# linea: 676598
# linea: 676599
# linea: 676600
# linea: 676601
# linea: 676602
# linea: 676603
# linea: 676604
# linea: 676605
# linea: 676606
# linea: 676607
# linea: 676608
# linea: 676609
# linea: 676610
# linea: 676611
# linea: 676612
# linea: 676613
# linea: 676614
# linea: 676615
# linea: 676616
# linea: 676617
# linea: 676618
# linea: 676619
# linea: 676620
# linea: 676621
# linea: 676622
# linea: 676623
# linea: 676624
# linea: 676625
# linea: 676626
# linea: 676627
# linea: 676628
# linea: 676629
# linea: 676630
# linea: 676631
# linea: 676632
# linea: 676633
# linea: 676634
# linea: 676635
# linea: 676636
# linea: 676637
# linea: 676638
# linea: 676639
# linea: 676640
# linea: 676641
# linea: 676642
# linea: 676643
# linea: 676644
# linea: 676645
# linea: 676646
# linea: 676647
# linea: 676648
# linea: 676649
# linea: 676650
# linea: 676651
# linea: 676652
# linea: 676653
# linea: 676654
# linea: 676655
# linea: 676656
# linea: 676657
# linea: 676658
# linea: 676659
# linea: 676660
# linea: 676661
# linea: 676662
# linea: 676663
# linea: 676664
# linea: 676665
# linea: 676666
# linea: 676667
# linea: 676668
# linea: 676669
# linea: 676670
# linea: 676671
# linea: 676672
# linea: 676673
# linea: 676674
# linea: 676675
# linea: 676676
# linea: 676677
# linea: 676678
# linea: 676679
# linea: 676680
# linea: 676681
# linea: 676682
# linea: 676683
# linea: 676684
# linea: 676685
# linea: 676686
# linea: 676687
# linea: 676688
# linea: 676689
# linea: 676690
# linea: 676691
# linea: 676692
# linea: 676693
# linea: 676694
# linea: 676695
# linea: 676696
# linea: 676697
# linea: 676698
# linea: 676699
# linea: 676700
# linea: 676701
# linea: 676702
# linea: 676703
# linea: 676704
# linea: 676705
# linea: 676706
# linea: 676707
# linea: 676708
# linea: 676709
# linea: 676710
# linea: 676711
# linea: 676712
# linea: 676713
# linea: 676714
# linea: 676715
# linea: 676716
# linea: 676717
# linea: 676718
# linea: 676719
# linea: 676720
# linea: 676721
# linea: 676722
# linea: 676723
# linea: 676724
# linea: 676725
# linea: 676726
# linea: 676727
# linea: 676728
# linea: 676729
# linea: 676730
# linea: 676731
# linea: 676732
# linea: 676733
# linea: 676734
# linea: 676735
# linea: 676736
# linea: 676737
# linea: 676738
# linea: 676739
# linea: 676740
# linea: 676741
# linea: 676742
# linea: 676743
# linea: 676744
# linea: 676745
# linea: 676746
# linea: 676747
# linea: 676748
# linea: 676749
# linea: 676750
# linea: 676751
# linea: 676752
# linea: 676753
# linea: 676754
# linea: 676755
# linea: 676756
# linea: 676757
# linea: 676758
# linea: 676759
# linea: 676760
# linea: 676761
# linea: 676762
# linea: 676763
# linea: 676764
# linea: 676765
# linea: 676766
# linea: 676767
# linea: 676768
# linea: 676769
# linea: 676770
# linea: 676771
# linea: 676772
# linea: 676773
# linea: 676774
# linea: 676775
# linea: 676776
# linea: 676777
# linea: 676778
# linea: 676779
# linea: 676780
# linea: 676781
# linea: 676782
# linea: 676783
# linea: 676784
# linea: 676785
# linea: 676786
# linea: 676787
# linea: 676788
# linea: 676789
# linea: 676790
# linea: 676791
# linea: 676792
# linea: 676793
# linea: 676794
# linea: 676795
# linea: 676796
# linea: 676797
# linea: 676798
# linea: 676799
# linea: 676800
# linea: 676801
# linea: 676802
# linea: 676803
# linea: 676804
# linea: 676805
# linea: 676806
# linea: 676807
# linea: 676808
# linea: 676809
# linea: 676810
# linea: 676811
# linea: 676812
# linea: 676813
# linea: 676814
# linea: 676815
# linea: 676816
# linea: 676817
# linea: 676818
# linea: 676819
# linea: 676820
# linea: 676821
# linea: 676822
# linea: 676823
# linea: 676824
# linea: 676825
# linea: 676826
# linea: 676827
# linea: 676828
# linea: 676829
# linea: 676830
# linea: 676831
# linea: 676832
# linea: 676833
# linea: 676834
# linea: 676835
# linea: 676836
# linea: 676837
# linea: 676838
# linea: 676839
# linea: 676840
# linea: 676841
# linea: 676842
# linea: 676843
# linea: 676844
# linea: 676845
# linea: 676846
# linea: 676847
# linea: 676848
# linea: 676849
# linea: 676850
# linea: 676851
# linea: 676852
# linea: 676853
# linea: 676854
# linea: 676855
# linea: 676856
# linea: 676857
# linea: 676858
# linea: 676859
# linea: 676860
# linea: 676861
# linea: 676862
# linea: 676863
# linea: 676864
# linea: 676865
# linea: 676866
# linea: 676867
# linea: 676868
# linea: 676869
# linea: 676870
# linea: 676871
# linea: 676872
# linea: 676873
# linea: 676874
# linea: 676875
# linea: 676876
# linea: 676877
# linea: 676878
# linea: 676879
# linea: 676880
# linea: 676881
# linea: 676882
# linea: 676883
# linea: 676884
# linea: 676885
# linea: 676886
# linea: 676887
# linea: 676888
# linea: 676889
# linea: 676890
# linea: 676891
# linea: 676892
# linea: 676893
# linea: 676894
# linea: 676895
# linea: 676896
# linea: 676897
# linea: 676898
# linea: 676899
# linea: 676900
# linea: 676901
# linea: 676902
# linea: 676903
# linea: 676904
# linea: 676905
# linea: 676906
# linea: 676907
# linea: 676908
# linea: 676909
# linea: 676910
# linea: 676911
# linea: 676912
# linea: 676913
# linea: 676914
# linea: 676915
# linea: 676916
# linea: 676917
# linea: 676918
# linea: 676919
# linea: 676920
# linea: 676921
# linea: 676922
# linea: 676923
# linea: 676924
# linea: 676925
# linea: 676926
# linea: 676927
# linea: 676928
# linea: 676929
# linea: 676930
# linea: 676931
# linea: 676932
# linea: 676933
# linea: 676934
# linea: 676935
# linea: 676936
# linea: 676937
# linea: 676938
# linea: 676939
# linea: 676940
# linea: 676941
# linea: 676942
# linea: 676943
# linea: 676944
# linea: 676945
# linea: 676946
# linea: 676947
# linea: 676948
# linea: 676949
# linea: 676950
# linea: 676951
# linea: 676952
# linea: 676953
# linea: 676954
# linea: 676955
# linea: 676956
# linea: 676957
# linea: 676958
# linea: 676959
# linea: 676960
# linea: 676961
# linea: 676962
# linea: 676963
# linea: 676964
# linea: 676965
# linea: 676966
# linea: 676967
# linea: 676968
# linea: 676969
# linea: 676970
# linea: 676971
# linea: 676972
# linea: 676973
# linea: 676974
# linea: 676975
# linea: 676976
# linea: 676977
# linea: 676978
# linea: 676979
# linea: 676980
# linea: 676981
# linea: 676982
# linea: 676983
# linea: 676984
# linea: 676985
# linea: 676986
# linea: 676987
# linea: 676988
# linea: 676989
# linea: 676990
# linea: 676991
# linea: 676992
# linea: 676993
# linea: 676994
# linea: 676995
# linea: 676996
# linea: 676997
# linea: 676998
# linea: 676999
# linea: 677000
# linea: 677001
# linea: 677002
# linea: 677003
# linea: 677004
# linea: 677005
# linea: 677006
# linea: 677007
# linea: 677008
# linea: 677009
# linea: 677010
# linea: 677011
# linea: 677012
# linea: 677013
# linea: 677014
# linea: 677015
# linea: 677016
# linea: 677017
# linea: 677018
# linea: 677019
# linea: 677020
# linea: 677021
# linea: 677022
# linea: 677023
# linea: 677024
# linea: 677025
# linea: 677026
# linea: 677027
# linea: 677028
# linea: 677029
# linea: 677030
# linea: 677031
# linea: 677032
# linea: 677033
# linea: 677034
# linea: 677035
# linea: 677036
# linea: 677037
# linea: 677038
# linea: 677039
# linea: 677040
# linea: 677041
# linea: 677042
# linea: 677043
# linea: 677044
# linea: 677045
# linea: 677046
# linea: 677047
# linea: 677048
# linea: 677049
# linea: 677050
# linea: 677051
# linea: 677052
# linea: 677053
# linea: 677054
# linea: 677055
# linea: 677056
# linea: 677057
# linea: 677058
# linea: 677059
# linea: 677060
# linea: 677061
# linea: 677062
# linea: 677063
# linea: 677064
# linea: 677065
# linea: 677066
# linea: 677067
# linea: 677068
# linea: 677069
# linea: 677070
# linea: 677071
# linea: 677072
# linea: 677073
# linea: 677074
# linea: 677075
# linea: 677076
# linea: 677077
# linea: 677078
# linea: 677079
# linea: 677080
# linea: 677081
# linea: 677082
# linea: 677083
# linea: 677084
# linea: 677085
# linea: 677086
# linea: 677087
# linea: 677088
# linea: 677089
# linea: 677090
# linea: 677091
# linea: 677092
# linea: 677093
# linea: 677094
# linea: 677095
# linea: 677096
# linea: 677097
# linea: 677098
# linea: 677099
# linea: 677100
# linea: 677101
# linea: 677102
# linea: 677103
# linea: 677104
# linea: 677105
# linea: 677106
# linea: 677107
# linea: 677108
# linea: 677109
# linea: 677110
# linea: 677111
# linea: 677112
# linea: 677113
# linea: 677114
# linea: 677115
# linea: 677116
# linea: 677117
# linea: 677118
# linea: 677119
# linea: 677120
# linea: 677121
# linea: 677122
# linea: 677123
# linea: 677124
# linea: 677125
# linea: 677126
# linea: 677127
# linea: 677128
# linea: 677129
# linea: 677130
# linea: 677131
# linea: 677132
# linea: 677133
# linea: 677134
# linea: 677135
# linea: 677136
# linea: 677137
# linea: 677138
# linea: 677139
# linea: 677140
# linea: 677141
# linea: 677142
# linea: 677143
# linea: 677144
# linea: 677145
# linea: 677146
# linea: 677147
# linea: 677148
# linea: 677149
# linea: 677150
# linea: 677151
# linea: 677152
# linea: 677153
# linea: 677154
# linea: 677155
# linea: 677156
# linea: 677157
# linea: 677158
# linea: 677159
# linea: 677160
# linea: 677161
# linea: 677162
# linea: 677163
# linea: 677164
# linea: 677165
# linea: 677166
# linea: 677167
# linea: 677168
# linea: 677169
# linea: 677170
# linea: 677171
# linea: 677172
# linea: 677173
# linea: 677174
# linea: 677175
# linea: 677176
# linea: 677177
# linea: 677178
# linea: 677179
# linea: 677180
# linea: 677181
# linea: 677182
# linea: 677183
# linea: 677184
# linea: 677185
# linea: 677186
# linea: 677187
# linea: 677188
# linea: 677189
# linea: 677190
# linea: 677191
# linea: 677192
# linea: 677193
# linea: 677194
# linea: 677195
# linea: 677196
# linea: 677197
# linea: 677198
# linea: 677199
# linea: 677200
# linea: 677201
# linea: 677202
# linea: 677203
# linea: 677204
# linea: 677205
# linea: 677206
# linea: 677207
# linea: 677208
# linea: 677209
# linea: 677210
# linea: 677211
# linea: 677212
# linea: 677213
# linea: 677214
# linea: 677215
# linea: 677216
# linea: 677217
# linea: 677218
# linea: 677219
# linea: 677220
# linea: 677221
# linea: 677222
# linea: 677223
# linea: 677224
# linea: 677225
# linea: 677226
# linea: 677227
# linea: 677228
# linea: 677229
# linea: 677230
# linea: 677231
# linea: 677232
# linea: 677233
# linea: 677234
# linea: 677235
# linea: 677236
# linea: 677237
# linea: 677238
# linea: 677239
# linea: 677240
# linea: 677241
# linea: 677242
# linea: 677243
# linea: 677244
# linea: 677245
# linea: 677246
# linea: 677247
# linea: 677248
# linea: 677249
# linea: 677250
# linea: 677251
# linea: 677252
# linea: 677253
# linea: 677254
# linea: 677255
# linea: 677256
# linea: 677257
# linea: 677258
# linea: 677259
# linea: 677260
# linea: 677261
# linea: 677262
# linea: 677263
# linea: 677264
# linea: 677265
# linea: 677266
# linea: 677267
# linea: 677268
# linea: 677269
# linea: 677270
# linea: 677271
# linea: 677272
# linea: 677273
# linea: 677274
# linea: 677275
# linea: 677276
# linea: 677277
# linea: 677278
# linea: 677279
# linea: 677280
# linea: 677281
# linea: 677282
# linea: 677283
# linea: 677284
# linea: 677285
# linea: 677286
# linea: 677287
# linea: 677288
# linea: 677289
# linea: 677290
# linea: 677291
# linea: 677292
# linea: 677293
# linea: 677294
# linea: 677295
# linea: 677296
# linea: 677297
# linea: 677298
# linea: 677299
# linea: 677300
# linea: 677301
# linea: 677302
# linea: 677303
# linea: 677304
# linea: 677305
# linea: 677306
# linea: 677307
# linea: 677308
# linea: 677309
# linea: 677310
# linea: 677311
# linea: 677312
# linea: 677313
# linea: 677314
# linea: 677315
# linea: 677316
# linea: 677317
# linea: 677318
# linea: 677319
# linea: 677320
# linea: 677321
# linea: 677322
# linea: 677323
# linea: 677324
# linea: 677325
# linea: 677326
# linea: 677327
# linea: 677328
# linea: 677329
# linea: 677330
# linea: 677331
# linea: 677332
# linea: 677333
# linea: 677334
# linea: 677335
# linea: 677336
# linea: 677337
# linea: 677338
# linea: 677339
# linea: 677340
# linea: 677341
# linea: 677342
# linea: 677343
# linea: 677344
# linea: 677345
# linea: 677346
# linea: 677347
# linea: 677348
# linea: 677349
# linea: 677350
# linea: 677351
# linea: 677352
# linea: 677353
# linea: 677354
# linea: 677355
# linea: 677356
# linea: 677357
# linea: 677358
# linea: 677359
# linea: 677360
# linea: 677361
# linea: 677362
# linea: 677363
# linea: 677364
# linea: 677365
# linea: 677366
# linea: 677367
# linea: 677368
# linea: 677369
# linea: 677370
# linea: 677371
# linea: 677372
# linea: 677373
# linea: 677374
# linea: 677375
# linea: 677376
# linea: 677377
# linea: 677378
# linea: 677379
# linea: 677380
# linea: 677381
# linea: 677382
# linea: 677383
# linea: 677384
# linea: 677385
# linea: 677386
# linea: 677387
# linea: 677388
# linea: 677389
# linea: 677390
# linea: 677391
# linea: 677392
# linea: 677393
# linea: 677394
# linea: 677395
# linea: 677396
# linea: 677397
# linea: 677398
# linea: 677399
# linea: 677400
# linea: 677401
# linea: 677402
# linea: 677403
# linea: 677404
# linea: 677405
# linea: 677406
# linea: 677407
# linea: 677408
# linea: 677409
# linea: 677410
# linea: 677411
# linea: 677412
# linea: 677413
# linea: 677414
# linea: 677415
# linea: 677416
# linea: 677417
# linea: 677418
# linea: 677419
# linea: 677420
# linea: 677421
# linea: 677422
# linea: 677423
# linea: 677424
# linea: 677425
# linea: 677426
# linea: 677427
# linea: 677428
# linea: 677429
# linea: 677430
# linea: 677431
# linea: 677432
# linea: 677433
# linea: 677434
# linea: 677435
# linea: 677436
# linea: 677437
# linea: 677438
# linea: 677439
# linea: 677440
# linea: 677441
# linea: 677442
# linea: 677443
# linea: 677444
# linea: 677445
# linea: 677446
# linea: 677447
# linea: 677448
# linea: 677449
# linea: 677450
# linea: 677451
# linea: 677452
# linea: 677453
# linea: 677454
# linea: 677455
# linea: 677456
# linea: 677457
# linea: 677458
# linea: 677459
# linea: 677460
# linea: 677461
# linea: 677462
# linea: 677463
# linea: 677464
# linea: 677465
# linea: 677466
# linea: 677467
# linea: 677468
# linea: 677469
# linea: 677470
# linea: 677471
# linea: 677472
# linea: 677473
# linea: 677474
# linea: 677475
# linea: 677476
# linea: 677477
# linea: 677478
# linea: 677479
# linea: 677480
# linea: 677481
# linea: 677482
# linea: 677483
# linea: 677484
# linea: 677485
# linea: 677486
# linea: 677487
# linea: 677488
# linea: 677489
# linea: 677490
# linea: 677491
# linea: 677492
# linea: 677493
# linea: 677494
# linea: 677495
# linea: 677496
# linea: 677497
# linea: 677498
# linea: 677499
# linea: 677500
# linea: 677501
# linea: 677502
# linea: 677503
# linea: 677504
# linea: 677505
# linea: 677506
# linea: 677507
# linea: 677508
# linea: 677509
# linea: 677510
# linea: 677511
# linea: 677512
# linea: 677513
# linea: 677514
# linea: 677515
# linea: 677516
# linea: 677517
# linea: 677518
# linea: 677519
# linea: 677520
# linea: 677521
# linea: 677522
# linea: 677523
# linea: 677524
# linea: 677525
# linea: 677526
# linea: 677527
# linea: 677528
# linea: 677529
# linea: 677530
# linea: 677531
# linea: 677532
# linea: 677533
# linea: 677534
# linea: 677535
# linea: 677536
# linea: 677537
# linea: 677538
# linea: 677539
# linea: 677540
# linea: 677541
# linea: 677542
# linea: 677543
# linea: 677544
# linea: 677545
# linea: 677546
# linea: 677547
# linea: 677548
# linea: 677549
# linea: 677550
# linea: 677551
# linea: 677552
# linea: 677553
# linea: 677554
# linea: 677555
# linea: 677556
# linea: 677557
# linea: 677558
# linea: 677559
# linea: 677560
# linea: 677561
# linea: 677562
# linea: 677563
# linea: 677564
# linea: 677565
# linea: 677566
# linea: 677567
# linea: 677568
# linea: 677569
# linea: 677570
# linea: 677571
# linea: 677572
# linea: 677573
# linea: 677574
# linea: 677575
# linea: 677576
# linea: 677577
# linea: 677578
# linea: 677579
# linea: 677580
# linea: 677581
# linea: 677582
# linea: 677583
# linea: 677584
# linea: 677585
# linea: 677586
# linea: 677587
# linea: 677588
# linea: 677589
# linea: 677590
# linea: 677591
# linea: 677592
# linea: 677593
# linea: 677594
# linea: 677595
# linea: 677596
# linea: 677597
# linea: 677598
# linea: 677599
# linea: 677600
# linea: 677601
# linea: 677602
# linea: 677603
# linea: 677604
# linea: 677605
# linea: 677606
# linea: 677607
# linea: 677608
# linea: 677609
# linea: 677610
# linea: 677611
# linea: 677612
# linea: 677613
# linea: 677614
# linea: 677615
# linea: 677616
# linea: 677617
# linea: 677618
# linea: 677619
# linea: 677620
# linea: 677621
# linea: 677622
# linea: 677623
# linea: 677624
# linea: 677625
# linea: 677626
# linea: 677627
# linea: 677628
# linea: 677629
# linea: 677630
# linea: 677631
# linea: 677632
# linea: 677633
# linea: 677634
# linea: 677635
# linea: 677636
# linea: 677637
# linea: 677638
# linea: 677639
# linea: 677640
# linea: 677641
# linea: 677642
# linea: 677643
# linea: 677644
# linea: 677645
# linea: 677646
# linea: 677647
# linea: 677648
# linea: 677649
# linea: 677650
# linea: 677651
# linea: 677652
# linea: 677653
# linea: 677654
# linea: 677655
# linea: 677656
# linea: 677657
# linea: 677658
# linea: 677659
# linea: 677660
# linea: 677661
# linea: 677662
# linea: 677663
# linea: 677664
# linea: 677665
# linea: 677666
# linea: 677667
# linea: 677668
# linea: 677669
# linea: 677670
# linea: 677671
# linea: 677672
# linea: 677673
# linea: 677674
# linea: 677675
# linea: 677676
# linea: 677677
# linea: 677678
# linea: 677679
# linea: 677680
# linea: 677681
# linea: 677682
# linea: 677683
# linea: 677684
# linea: 677685
# linea: 677686
# linea: 677687
# linea: 677688
# linea: 677689
# linea: 677690
# linea: 677691
# linea: 677692
# linea: 677693
# linea: 677694
# linea: 677695
# linea: 677696
# linea: 677697
# linea: 677698
# linea: 677699
# linea: 677700
# linea: 677701
# linea: 677702
# linea: 677703
# linea: 677704
# linea: 677705
# linea: 677706
# linea: 677707
# linea: 677708
# linea: 677709
# linea: 677710
# linea: 677711
# linea: 677712
# linea: 677713
# linea: 677714
# linea: 677715
# linea: 677716
# linea: 677717
# linea: 677718
# linea: 677719
# linea: 677720
# linea: 677721
# linea: 677722
# linea: 677723
# linea: 677724
# linea: 677725
# linea: 677726
# linea: 677727
# linea: 677728
# linea: 677729
# linea: 677730
# linea: 677731
# linea: 677732
# linea: 677733
# linea: 677734
# linea: 677735
# linea: 677736
# linea: 677737
# linea: 677738
# linea: 677739
# linea: 677740
# linea: 677741
# linea: 677742
# linea: 677743
# linea: 677744
# linea: 677745
# linea: 677746
# linea: 677747
# linea: 677748
# linea: 677749
# linea: 677750
# linea: 677751
# linea: 677752
# linea: 677753
# linea: 677754
# linea: 677755
# linea: 677756
# linea: 677757
# linea: 677758
# linea: 677759
# linea: 677760
# linea: 677761
# linea: 677762
# linea: 677763
# linea: 677764
# linea: 677765
# linea: 677766
# linea: 677767
# linea: 677768
# linea: 677769
# linea: 677770
# linea: 677771
# linea: 677772
# linea: 677773
# linea: 677774
# linea: 677775
# linea: 677776
# linea: 677777
# linea: 677778
# linea: 677779
# linea: 677780
# linea: 677781
# linea: 677782
# linea: 677783
# linea: 677784
# linea: 677785
# linea: 677786
# linea: 677787
# linea: 677788
# linea: 677789
# linea: 677790
# linea: 677791
# linea: 677792
# linea: 677793
# linea: 677794
# linea: 677795
# linea: 677796
# linea: 677797
# linea: 677798
# linea: 677799
# linea: 677800
# linea: 677801
# linea: 677802
# linea: 677803
# linea: 677804
# linea: 677805
# linea: 677806
# linea: 677807
# linea: 677808
# linea: 677809
# linea: 677810
# linea: 677811
# linea: 677812
# linea: 677813
# linea: 677814
# linea: 677815
# linea: 677816
# linea: 677817
# linea: 677818
# linea: 677819
# linea: 677820
# linea: 677821
# linea: 677822
# linea: 677823
# linea: 677824
# linea: 677825
# linea: 677826
# linea: 677827
# linea: 677828
# linea: 677829
# linea: 677830
# linea: 677831
# linea: 677832
# linea: 677833
# linea: 677834
# linea: 677835
# linea: 677836
# linea: 677837
# linea: 677838
# linea: 677839
# linea: 677840
# linea: 677841
# linea: 677842
# linea: 677843
# linea: 677844
# linea: 677845
# linea: 677846
# linea: 677847
# linea: 677848
# linea: 677849
# linea: 677850
# linea: 677851
# linea: 677852
# linea: 677853
# linea: 677854
# linea: 677855
# linea: 677856
# linea: 677857
# linea: 677858
# linea: 677859
# linea: 677860
# linea: 677861
# linea: 677862
# linea: 677863
# linea: 677864
# linea: 677865
# linea: 677866
# linea: 677867
# linea: 677868
# linea: 677869
# linea: 677870
# linea: 677871
# linea: 677872
# linea: 677873
# linea: 677874
# linea: 677875
# linea: 677876
# linea: 677877
# linea: 677878
# linea: 677879
# linea: 677880
# linea: 677881
# linea: 677882
# linea: 677883
# linea: 677884
# linea: 677885
# linea: 677886
# linea: 677887
# linea: 677888
# linea: 677889
# linea: 677890
# linea: 677891
# linea: 677892
# linea: 677893
# linea: 677894
# linea: 677895
# linea: 677896
# linea: 677897
# linea: 677898
# linea: 677899
# linea: 677900
# linea: 677901
# linea: 677902
# linea: 677903
# linea: 677904
# linea: 677905
# linea: 677906
# linea: 677907
# linea: 677908
# linea: 677909
# linea: 677910
# linea: 677911
# linea: 677912
# linea: 677913
# linea: 677914
# linea: 677915
# linea: 677916
# linea: 677917
# linea: 677918
# linea: 677919
# linea: 677920
# linea: 677921
# linea: 677922
# linea: 677923
# linea: 677924
# linea: 677925
# linea: 677926
# linea: 677927
# linea: 677928
# linea: 677929
# linea: 677930
# linea: 677931
# linea: 677932
# linea: 677933
# linea: 677934
# linea: 677935
# linea: 677936
# linea: 677937
# linea: 677938
# linea: 677939
# linea: 677940
# linea: 677941
# linea: 677942
# linea: 677943
# linea: 677944
# linea: 677945
# linea: 677946
# linea: 677947
# linea: 677948
# linea: 677949
# linea: 677950
# linea: 677951
# linea: 677952
# linea: 677953
# linea: 677954
# linea: 677955
# linea: 677956
# linea: 677957
# linea: 677958
# linea: 677959
# linea: 677960
# linea: 677961
# linea: 677962
# linea: 677963
# linea: 677964
# linea: 677965
# linea: 677966
# linea: 677967
# linea: 677968
# linea: 677969
# linea: 677970
# linea: 677971
# linea: 677972
# linea: 677973
# linea: 677974
# linea: 677975
# linea: 677976
# linea: 677977
# linea: 677978
# linea: 677979
# linea: 677980
# linea: 677981
# linea: 677982
# linea: 677983
# linea: 677984
# linea: 677985
# linea: 677986
# linea: 677987
# linea: 677988
# linea: 677989
# linea: 677990
# linea: 677991
# linea: 677992
# linea: 677993
# linea: 677994
# linea: 677995
# linea: 677996
# linea: 677997
# linea: 677998
# linea: 677999
# linea: 678000
# linea: 678001
# linea: 678002
# linea: 678003
# linea: 678004
# linea: 678005
# linea: 678006
# linea: 678007
# linea: 678008
# linea: 678009
# linea: 678010
# linea: 678011
# linea: 678012
# linea: 678013
# linea: 678014
# linea: 678015
# linea: 678016
# linea: 678017
# linea: 678018
# linea: 678019
# linea: 678020
# linea: 678021
# linea: 678022
# linea: 678023
# linea: 678024
# linea: 678025
# linea: 678026
# linea: 678027
# linea: 678028
# linea: 678029
# linea: 678030
# linea: 678031
# linea: 678032
# linea: 678033
# linea: 678034
# linea: 678035
# linea: 678036
# linea: 678037
# linea: 678038
# linea: 678039
# linea: 678040
# linea: 678041
# linea: 678042
# linea: 678043
# linea: 678044
# linea: 678045
# linea: 678046
# linea: 678047
# linea: 678048
# linea: 678049
# linea: 678050
# linea: 678051
# linea: 678052
# linea: 678053
# linea: 678054
# linea: 678055
# linea: 678056
# linea: 678057
# linea: 678058
# linea: 678059
# linea: 678060
# linea: 678061
# linea: 678062
# linea: 678063
# linea: 678064
# linea: 678065
# linea: 678066
# linea: 678067
# linea: 678068
# linea: 678069
# linea: 678070
# linea: 678071
# linea: 678072
# linea: 678073
# linea: 678074
# linea: 678075
# linea: 678076
# linea: 678077
# linea: 678078
# linea: 678079
# linea: 678080
# linea: 678081
# linea: 678082
# linea: 678083
# linea: 678084
# linea: 678085
# linea: 678086
# linea: 678087
# linea: 678088
# linea: 678089
# linea: 678090
# linea: 678091
# linea: 678092
# linea: 678093
# linea: 678094
# linea: 678095
# linea: 678096
# linea: 678097
# linea: 678098
# linea: 678099
# linea: 678100
# linea: 678101
# linea: 678102
# linea: 678103
# linea: 678104
# linea: 678105
# linea: 678106
# linea: 678107
# linea: 678108
# linea: 678109
# linea: 678110
# linea: 678111
# linea: 678112
# linea: 678113
# linea: 678114
# linea: 678115
# linea: 678116
# linea: 678117
# linea: 678118
# linea: 678119
# linea: 678120
# linea: 678121
# linea: 678122
# linea: 678123
# linea: 678124
# linea: 678125
# linea: 678126
# linea: 678127
# linea: 678128
# linea: 678129
# linea: 678130
# linea: 678131
# linea: 678132
# linea: 678133
# linea: 678134
# linea: 678135
# linea: 678136
# linea: 678137
# linea: 678138
# linea: 678139
# linea: 678140
# linea: 678141
# linea: 678142
# linea: 678143
# linea: 678144
# linea: 678145
# linea: 678146
# linea: 678147
# linea: 678148
# linea: 678149
# linea: 678150
# linea: 678151
# linea: 678152
# linea: 678153
# linea: 678154
# linea: 678155
# linea: 678156
# linea: 678157
# linea: 678158
# linea: 678159
# linea: 678160
# linea: 678161
# linea: 678162
# linea: 678163
# linea: 678164
# linea: 678165
# linea: 678166
# linea: 678167
# linea: 678168
# linea: 678169
# linea: 678170
# linea: 678171
# linea: 678172
# linea: 678173
# linea: 678174
# linea: 678175
# linea: 678176
# linea: 678177
# linea: 678178
# linea: 678179
# linea: 678180
# linea: 678181
# linea: 678182
# linea: 678183
# linea: 678184
# linea: 678185
# linea: 678186
# linea: 678187
# linea: 678188
# linea: 678189
# linea: 678190
# linea: 678191
# linea: 678192
# linea: 678193
# linea: 678194
# linea: 678195
# linea: 678196
# linea: 678197
# linea: 678198
# linea: 678199
# linea: 678200
# linea: 678201
# linea: 678202
# linea: 678203
# linea: 678204
# linea: 678205
# linea: 678206
# linea: 678207
# linea: 678208
# linea: 678209
# linea: 678210
# linea: 678211
# linea: 678212
# linea: 678213
# linea: 678214
# linea: 678215
# linea: 678216
# linea: 678217
# linea: 678218
# linea: 678219
# linea: 678220
# linea: 678221
# linea: 678222
# linea: 678223
# linea: 678224
# linea: 678225
# linea: 678226
# linea: 678227
# linea: 678228
# linea: 678229
# linea: 678230
# linea: 678231
# linea: 678232
# linea: 678233
# linea: 678234
# linea: 678235
# linea: 678236
# linea: 678237
# linea: 678238
# linea: 678239
# linea: 678240
# linea: 678241
# linea: 678242
# linea: 678243
# linea: 678244
# linea: 678245
# linea: 678246
# linea: 678247
# linea: 678248
# linea: 678249
# linea: 678250
# linea: 678251
# linea: 678252
# linea: 678253
# linea: 678254
# linea: 678255
# linea: 678256
# linea: 678257
# linea: 678258
# linea: 678259
# linea: 678260
# linea: 678261
# linea: 678262
# linea: 678263
# linea: 678264
# linea: 678265
# linea: 678266
# linea: 678267
# linea: 678268
# linea: 678269
# linea: 678270
# linea: 678271
# linea: 678272
# linea: 678273
# linea: 678274
# linea: 678275
# linea: 678276
# linea: 678277
# linea: 678278
# linea: 678279
# linea: 678280
# linea: 678281
# linea: 678282
# linea: 678283
# linea: 678284
# linea: 678285
# linea: 678286
# linea: 678287
# linea: 678288
# linea: 678289
# linea: 678290
# linea: 678291
# linea: 678292
# linea: 678293
# linea: 678294
# linea: 678295
# linea: 678296
# linea: 678297
# linea: 678298
# linea: 678299
# linea: 678300
# linea: 678301
# linea: 678302
# linea: 678303
# linea: 678304
# linea: 678305
# linea: 678306
# linea: 678307
# linea: 678308
# linea: 678309
# linea: 678310
# linea: 678311
# linea: 678312
# linea: 678313
# linea: 678314
# linea: 678315
# linea: 678316
# linea: 678317
# linea: 678318
# linea: 678319
# linea: 678320
# linea: 678321
# linea: 678322
# linea: 678323
# linea: 678324
# linea: 678325
# linea: 678326
# linea: 678327
# linea: 678328
# linea: 678329
# linea: 678330
# linea: 678331
# linea: 678332
# linea: 678333
# linea: 678334
# linea: 678335
# linea: 678336
# linea: 678337
# linea: 678338
# linea: 678339
# linea: 678340
# linea: 678341
# linea: 678342
# linea: 678343
# linea: 678344
# linea: 678345
# linea: 678346
# linea: 678347
# linea: 678348
# linea: 678349
# linea: 678350
# linea: 678351
# linea: 678352
# linea: 678353
# linea: 678354
# linea: 678355
# linea: 678356
# linea: 678357
# linea: 678358
# linea: 678359
# linea: 678360
# linea: 678361
# linea: 678362
# linea: 678363
# linea: 678364
# linea: 678365
# linea: 678366
# linea: 678367
# linea: 678368
# linea: 678369
# linea: 678370
# linea: 678371
# linea: 678372
# linea: 678373
# linea: 678374
# linea: 678375
# linea: 678376
# linea: 678377
# linea: 678378
# linea: 678379
# linea: 678380
# linea: 678381
# linea: 678382
# linea: 678383
# linea: 678384
# linea: 678385
# linea: 678386
# linea: 678387
# linea: 678388
# linea: 678389
# linea: 678390
# linea: 678391
# linea: 678392
# linea: 678393
# linea: 678394
# linea: 678395
# linea: 678396
# linea: 678397
# linea: 678398
# linea: 678399
# linea: 678400
# linea: 678401
# linea: 678402
# linea: 678403
# linea: 678404
# linea: 678405
# linea: 678406
# linea: 678407
# linea: 678408
# linea: 678409
# linea: 678410
# linea: 678411
# linea: 678412
# linea: 678413
# linea: 678414
# linea: 678415
# linea: 678416
# linea: 678417
# linea: 678418
# linea: 678419
# linea: 678420
# linea: 678421
# linea: 678422
# linea: 678423
# linea: 678424
# linea: 678425
# linea: 678426
# linea: 678427
# linea: 678428
# linea: 678429
# linea: 678430
# linea: 678431
# linea: 678432
# linea: 678433
# linea: 678434
# linea: 678435
# linea: 678436
# linea: 678437
# linea: 678438
# linea: 678439
# linea: 678440
# linea: 678441
# linea: 678442
# linea: 678443
# linea: 678444
# linea: 678445
# linea: 678446
# linea: 678447
# linea: 678448
# linea: 678449
# linea: 678450
# linea: 678451
# linea: 678452
# linea: 678453
# linea: 678454
# linea: 678455
# linea: 678456
# linea: 678457
# linea: 678458
# linea: 678459
# linea: 678460
# linea: 678461
# linea: 678462
# linea: 678463
# linea: 678464
# linea: 678465
# linea: 678466
# linea: 678467
# linea: 678468
# linea: 678469
# linea: 678470
# linea: 678471
# linea: 678472
# linea: 678473
# linea: 678474
# linea: 678475
# linea: 678476
# linea: 678477
# linea: 678478
# linea: 678479
# linea: 678480
# linea: 678481
# linea: 678482
# linea: 678483
# linea: 678484
# linea: 678485
# linea: 678486
# linea: 678487
# linea: 678488
# linea: 678489
# linea: 678490
# linea: 678491
# linea: 678492
# linea: 678493
# linea: 678494
# linea: 678495
# linea: 678496
# linea: 678497
# linea: 678498
# linea: 678499
# linea: 678500
# linea: 678501
# linea: 678502
# linea: 678503
# linea: 678504
# linea: 678505
# linea: 678506
# linea: 678507
# linea: 678508
# linea: 678509
# linea: 678510
# linea: 678511
# linea: 678512
# linea: 678513
# linea: 678514
# linea: 678515
# linea: 678516
# linea: 678517
# linea: 678518
# linea: 678519
# linea: 678520
# linea: 678521
# linea: 678522
# linea: 678523
# linea: 678524
# linea: 678525
# linea: 678526
# linea: 678527
# linea: 678528
# linea: 678529
# linea: 678530
# linea: 678531
# linea: 678532
# linea: 678533
# linea: 678534
# linea: 678535
# linea: 678536
# linea: 678537
# linea: 678538
# linea: 678539
# linea: 678540
# linea: 678541
# linea: 678542
# linea: 678543
# linea: 678544
# linea: 678545
# linea: 678546
# linea: 678547
# linea: 678548
# linea: 678549
# linea: 678550
# linea: 678551
# linea: 678552
# linea: 678553
# linea: 678554
# linea: 678555
# linea: 678556
# linea: 678557
# linea: 678558
# linea: 678559
# linea: 678560
# linea: 678561
# linea: 678562
# linea: 678563
# linea: 678564
# linea: 678565
# linea: 678566
# linea: 678567
# linea: 678568
# linea: 678569
# linea: 678570
# linea: 678571
# linea: 678572
# linea: 678573
# linea: 678574
# linea: 678575
# linea: 678576
# linea: 678577
# linea: 678578
# linea: 678579
# linea: 678580
# linea: 678581
# linea: 678582
# linea: 678583
# linea: 678584
# linea: 678585
# linea: 678586
# linea: 678587
# linea: 678588
# linea: 678589
# linea: 678590
# linea: 678591
# linea: 678592
# linea: 678593
# linea: 678594
# linea: 678595
# linea: 678596
# linea: 678597
# linea: 678598
# linea: 678599
# linea: 678600
# linea: 678601
# linea: 678602
# linea: 678603
# linea: 678604
# linea: 678605
# linea: 678606
# linea: 678607
# linea: 678608
# linea: 678609
# linea: 678610
# linea: 678611
# linea: 678612
# linea: 678613
# linea: 678614
# linea: 678615
# linea: 678616
# linea: 678617
# linea: 678618
# linea: 678619
# linea: 678620
# linea: 678621
# linea: 678622
# linea: 678623
# linea: 678624
# linea: 678625
# linea: 678626
# linea: 678627
# linea: 678628
# linea: 678629
# linea: 678630
# linea: 678631
# linea: 678632
# linea: 678633
# linea: 678634
# linea: 678635
# linea: 678636
# linea: 678637
# linea: 678638
# linea: 678639
# linea: 678640
# linea: 678641
# linea: 678642
# linea: 678643
# linea: 678644
# linea: 678645
# linea: 678646
# linea: 678647
# linea: 678648
# linea: 678649
# linea: 678650
# linea: 678651
# linea: 678652
# linea: 678653
# linea: 678654
# linea: 678655
# linea: 678656
# linea: 678657
# linea: 678658
# linea: 678659
# linea: 678660
# linea: 678661
# linea: 678662
# linea: 678663
# linea: 678664
# linea: 678665
# linea: 678666
# linea: 678667
# linea: 678668
# linea: 678669
# linea: 678670
# linea: 678671
# linea: 678672
# linea: 678673
# linea: 678674
# linea: 678675
# linea: 678676
# linea: 678677
# linea: 678678
# linea: 678679
# linea: 678680
# linea: 678681
# linea: 678682
# linea: 678683
# linea: 678684
# linea: 678685
# linea: 678686
# linea: 678687
# linea: 678688
# linea: 678689
# linea: 678690
# linea: 678691
# linea: 678692
# linea: 678693
# linea: 678694
# linea: 678695
# linea: 678696
# linea: 678697
# linea: 678698
# linea: 678699
# linea: 678700
# linea: 678701
# linea: 678702
# linea: 678703
# linea: 678704
# linea: 678705
# linea: 678706
# linea: 678707
# linea: 678708
# linea: 678709
# linea: 678710
# linea: 678711
# linea: 678712
# linea: 678713
# linea: 678714
# linea: 678715
# linea: 678716
# linea: 678717
# linea: 678718
# linea: 678719
# linea: 678720
# linea: 678721
# linea: 678722
# linea: 678723
# linea: 678724
# linea: 678725
# linea: 678726
# linea: 678727
# linea: 678728
# linea: 678729
# linea: 678730
# linea: 678731
# linea: 678732
# linea: 678733
# linea: 678734
# linea: 678735
# linea: 678736
# linea: 678737
# linea: 678738
# linea: 678739
# linea: 678740
# linea: 678741
# linea: 678742
# linea: 678743
# linea: 678744
# linea: 678745
# linea: 678746
# linea: 678747
# linea: 678748
# linea: 678749
# linea: 678750
# linea: 678751
# linea: 678752
# linea: 678753
# linea: 678754
# linea: 678755
# linea: 678756
# linea: 678757
# linea: 678758
# linea: 678759
# linea: 678760
# linea: 678761
# linea: 678762
# linea: 678763
# linea: 678764
# linea: 678765
# linea: 678766
# linea: 678767
# linea: 678768
# linea: 678769
# linea: 678770
# linea: 678771
# linea: 678772
# linea: 678773
# linea: 678774
# linea: 678775
# linea: 678776
# linea: 678777
# linea: 678778
# linea: 678779
# linea: 678780
# linea: 678781
# linea: 678782
# linea: 678783
# linea: 678784
# linea: 678785
# linea: 678786
# linea: 678787
# linea: 678788
# linea: 678789
# linea: 678790
# linea: 678791
# linea: 678792
# linea: 678793
# linea: 678794
# linea: 678795
# linea: 678796
# linea: 678797
# linea: 678798
# linea: 678799
# linea: 678800
# linea: 678801
# linea: 678802
# linea: 678803
# linea: 678804
# linea: 678805
# linea: 678806
# linea: 678807
# linea: 678808
# linea: 678809
# linea: 678810
# linea: 678811
# linea: 678812
# linea: 678813
# linea: 678814
# linea: 678815
# linea: 678816
# linea: 678817
# linea: 678818
# linea: 678819
# linea: 678820
# linea: 678821
# linea: 678822
# linea: 678823
# linea: 678824
# linea: 678825
# linea: 678826
# linea: 678827
# linea: 678828
# linea: 678829
# linea: 678830
# linea: 678831
# linea: 678832
# linea: 678833
# linea: 678834
# linea: 678835
# linea: 678836
# linea: 678837
# linea: 678838
# linea: 678839
# linea: 678840
# linea: 678841
# linea: 678842
# linea: 678843
# linea: 678844
# linea: 678845
# linea: 678846
# linea: 678847
# linea: 678848
# linea: 678849
# linea: 678850
# linea: 678851
# linea: 678852
# linea: 678853
# linea: 678854
# linea: 678855
# linea: 678856
# linea: 678857
# linea: 678858
# linea: 678859
# linea: 678860
# linea: 678861
# linea: 678862
# linea: 678863
# linea: 678864
# linea: 678865
# linea: 678866
# linea: 678867
# linea: 678868
# linea: 678869
# linea: 678870
# linea: 678871
# linea: 678872
# linea: 678873
# linea: 678874
# linea: 678875
# linea: 678876
# linea: 678877
# linea: 678878
# linea: 678879
# linea: 678880
# linea: 678881
# linea: 678882
# linea: 678883
# linea: 678884
# linea: 678885
# linea: 678886
# linea: 678887
# linea: 678888
# linea: 678889
# linea: 678890
# linea: 678891
# linea: 678892
# linea: 678893
# linea: 678894
# linea: 678895
# linea: 678896
# linea: 678897
# linea: 678898
# linea: 678899
# linea: 678900
# linea: 678901
# linea: 678902
# linea: 678903
# linea: 678904
# linea: 678905
# linea: 678906
# linea: 678907
# linea: 678908
# linea: 678909
# linea: 678910
# linea: 678911
# linea: 678912
# linea: 678913
# linea: 678914
# linea: 678915
# linea: 678916
# linea: 678917
# linea: 678918
# linea: 678919
# linea: 678920
# linea: 678921
# linea: 678922
# linea: 678923
# linea: 678924
# linea: 678925
# linea: 678926
# linea: 678927
# linea: 678928
# linea: 678929
# linea: 678930
# linea: 678931
# linea: 678932
# linea: 678933
# linea: 678934
# linea: 678935
# linea: 678936
# linea: 678937
# linea: 678938
# linea: 678939
# linea: 678940
# linea: 678941
# linea: 678942
# linea: 678943
# linea: 678944
# linea: 678945
# linea: 678946
# linea: 678947
# linea: 678948
# linea: 678949
# linea: 678950
# linea: 678951
# linea: 678952
# linea: 678953
# linea: 678954
# linea: 678955
# linea: 678956
# linea: 678957
# linea: 678958
# linea: 678959
# linea: 678960
# linea: 678961
# linea: 678962
# linea: 678963
# linea: 678964
# linea: 678965
# linea: 678966
# linea: 678967
# linea: 678968
# linea: 678969
# linea: 678970
# linea: 678971
# linea: 678972
# linea: 678973
# linea: 678974
# linea: 678975
# linea: 678976
# linea: 678977
# linea: 678978
# linea: 678979
# linea: 678980
# linea: 678981
# linea: 678982
# linea: 678983
# linea: 678984
# linea: 678985
# linea: 678986
# linea: 678987
# linea: 678988
# linea: 678989
# linea: 678990
# linea: 678991
# linea: 678992
# linea: 678993
# linea: 678994
# linea: 678995
# linea: 678996
# linea: 678997
# linea: 678998
# linea: 678999
# linea: 679000
# linea: 679001
# linea: 679002
# linea: 679003
# linea: 679004
# linea: 679005
# linea: 679006
# linea: 679007
# linea: 679008
# linea: 679009
# linea: 679010
# linea: 679011
# linea: 679012
# linea: 679013
# linea: 679014
# linea: 679015
# linea: 679016
# linea: 679017
# linea: 679018
# linea: 679019
# linea: 679020
# linea: 679021
# linea: 679022
# linea: 679023
# linea: 679024
# linea: 679025
# linea: 679026
# linea: 679027
# linea: 679028
# linea: 679029
# linea: 679030
# linea: 679031
# linea: 679032
# linea: 679033
# linea: 679034
# linea: 679035
# linea: 679036
# linea: 679037
# linea: 679038
# linea: 679039
# linea: 679040
# linea: 679041
# linea: 679042
# linea: 679043
# linea: 679044
# linea: 679045
# linea: 679046
# linea: 679047
# linea: 679048
# linea: 679049
# linea: 679050
# linea: 679051
# linea: 679052
# linea: 679053
# linea: 679054
# linea: 679055
# linea: 679056
# linea: 679057
# linea: 679058
# linea: 679059
# linea: 679060
# linea: 679061
# linea: 679062
# linea: 679063
# linea: 679064
# linea: 679065
# linea: 679066
# linea: 679067
# linea: 679068
# linea: 679069
# linea: 679070
# linea: 679071
# linea: 679072
# linea: 679073
# linea: 679074
# linea: 679075
# linea: 679076
# linea: 679077
# linea: 679078
# linea: 679079
# linea: 679080
# linea: 679081
# linea: 679082
# linea: 679083
# linea: 679084
# linea: 679085
# linea: 679086
# linea: 679087
# linea: 679088
# linea: 679089
# linea: 679090
# linea: 679091
# linea: 679092
# linea: 679093
# linea: 679094
# linea: 679095
# linea: 679096
# linea: 679097
# linea: 679098
# linea: 679099
# linea: 679100
# linea: 679101
# linea: 679102
# linea: 679103
# linea: 679104
# linea: 679105
# linea: 679106
# linea: 679107
# linea: 679108
# linea: 679109
# linea: 679110
# linea: 679111
# linea: 679112
# linea: 679113
# linea: 679114
# linea: 679115
# linea: 679116
# linea: 679117
# linea: 679118
# linea: 679119
# linea: 679120
# linea: 679121
# linea: 679122
# linea: 679123
# linea: 679124
# linea: 679125
# linea: 679126
# linea: 679127
# linea: 679128
# linea: 679129
# linea: 679130
# linea: 679131
# linea: 679132
# linea: 679133
# linea: 679134
# linea: 679135
# linea: 679136
# linea: 679137
# linea: 679138
# linea: 679139
# linea: 679140
# linea: 679141
# linea: 679142
# linea: 679143
# linea: 679144
# linea: 679145
# linea: 679146
# linea: 679147
# linea: 679148
# linea: 679149
# linea: 679150
# linea: 679151
# linea: 679152
# linea: 679153
# linea: 679154
# linea: 679155
# linea: 679156
# linea: 679157
# linea: 679158
# linea: 679159
# linea: 679160
# linea: 679161
# linea: 679162
# linea: 679163
# linea: 679164
# linea: 679165
# linea: 679166
# linea: 679167
# linea: 679168
# linea: 679169
# linea: 679170
# linea: 679171
# linea: 679172
# linea: 679173
# linea: 679174
# linea: 679175
# linea: 679176
# linea: 679177
# linea: 679178
# linea: 679179
# linea: 679180
# linea: 679181
# linea: 679182
# linea: 679183
# linea: 679184
# linea: 679185
# linea: 679186
# linea: 679187
# linea: 679188
# linea: 679189
# linea: 679190
# linea: 679191
# linea: 679192
# linea: 679193
# linea: 679194
# linea: 679195
# linea: 679196
# linea: 679197
# linea: 679198
# linea: 679199
# linea: 679200
# linea: 679201
# linea: 679202
# linea: 679203
# linea: 679204
# linea: 679205
# linea: 679206
# linea: 679207
# linea: 679208
# linea: 679209
# linea: 679210
# linea: 679211
# linea: 679212
# linea: 679213
# linea: 679214
# linea: 679215
# linea: 679216
# linea: 679217
# linea: 679218
# linea: 679219
# linea: 679220
# linea: 679221
# linea: 679222
# linea: 679223
# linea: 679224
# linea: 679225
# linea: 679226
# linea: 679227
# linea: 679228
# linea: 679229
# linea: 679230
# linea: 679231
# linea: 679232
# linea: 679233
# linea: 679234
# linea: 679235
# linea: 679236
# linea: 679237
# linea: 679238
# linea: 679239
# linea: 679240
# linea: 679241
# linea: 679242
# linea: 679243
# linea: 679244
# linea: 679245
# linea: 679246
# linea: 679247
# linea: 679248
# linea: 679249
# linea: 679250
# linea: 679251
# linea: 679252
# linea: 679253
# linea: 679254
# linea: 679255
# linea: 679256
# linea: 679257
# linea: 679258
# linea: 679259
# linea: 679260
# linea: 679261
# linea: 679262
# linea: 679263
# linea: 679264
# linea: 679265
# linea: 679266
# linea: 679267
# linea: 679268
# linea: 679269
# linea: 679270
# linea: 679271
# linea: 679272
# linea: 679273
# linea: 679274
# linea: 679275
# linea: 679276
# linea: 679277
# linea: 679278
# linea: 679279
# linea: 679280
# linea: 679281
# linea: 679282
# linea: 679283
# linea: 679284
# linea: 679285
# linea: 679286
# linea: 679287
# linea: 679288
# linea: 679289
# linea: 679290
# linea: 679291
# linea: 679292
# linea: 679293
# linea: 679294
# linea: 679295
# linea: 679296
# linea: 679297
# linea: 679298
# linea: 679299
# linea: 679300
# linea: 679301
# linea: 679302
# linea: 679303
# linea: 679304
# linea: 679305
# linea: 679306
# linea: 679307
# linea: 679308
# linea: 679309
# linea: 679310
# linea: 679311
# linea: 679312
# linea: 679313
# linea: 679314
# linea: 679315
# linea: 679316
# linea: 679317
# ...
# linea: 679761
# linea: 679762
# linea: 679763
# linea: 679764
# linea: 679765
# linea: 679766
# linea: 679767
# linea: 679768
# linea: 679769
# linea: 679770
# linea: 679771
# linea: 679772
# linea: 679773
# linea: 679774
# linea: 679775
# linea: 679776
# linea: 679777
# linea: 679778
# linea: 679779
# linea: 679780
# linea: 679781
# linea: 679782
# linea: 679783
# linea: 679784
# linea: 679785
# linea: 679786
# linea: 679787
# linea: 679788
# linea: 679789
# linea: 679790
# linea: 679791
# linea: 679792
# linea: 679793
# linea: 679794
# linea: 679795
# linea: 679796
# linea: 679797
# linea: 679798
# linea: 679799
# linea: 679800
# linea: 679801
# linea: 679802
# linea: 679803
# linea: 679804
# linea: 679805
# linea: 679806
# linea: 679807
# linea: 679808
# linea: 679809
# linea: 679810
# linea: 679811
# linea: 679812
# linea: 679813
# linea: 679814
# linea: 679815
# linea: 679816
# linea: 679817
# linea: 679818
# linea: 679819
# linea: 679820
# linea: 679821
# linea: 679822
# linea: 679823
# linea: 679824
# linea: 679825
# linea: 679826
# linea: 679827
# linea: 679828
# linea: 679829
# linea: 679830
# linea: 679831
# linea: 679832
# linea: 679833
# linea: 679834
# linea: 679835
# linea: 679836
# linea: 679837
# linea: 679838
# linea: 679839
# linea: 679840
# linea: 679841
# linea: 679842
# linea: 679843
# linea: 679844
# linea: 679845
# linea: 679846
# linea: 679847
# linea: 679848
# linea: 679849
# linea: 679850
# linea: 679851
# linea: 679852
# linea: 679853
# linea: 679854
# linea: 679855
# linea: 679856
# linea: 679857
# linea: 679858
# linea: 679859
# linea: 679860
# linea: 679861
# linea: 679862
# linea: 679863
# linea: 679864
# linea: 679865
# linea: 679866
# linea: 679867
# linea: 679868
# linea: 679869
# linea: 679870
# linea: 679871
# linea: 679872
# linea: 679873
# linea: 679874
# linea: 679875
# linea: 679876
# linea: 679877
# linea: 679878
# linea: 679879
# linea: 679880
# linea: 679881
# linea: 679882
# linea: 679883
# linea: 679884
# linea: 679885
# linea: 679886
# linea: 679887
# linea: 679888
# linea: 679889
# linea: 679890
# linea: 679891
# linea: 679892
# linea: 679893
# linea: 679894
# linea: 679895
# linea: 679896
# linea: 679897
# linea: 679898
# linea: 679899
# linea: 679900
# linea: 679901
# linea: 679902
# linea: 679903
# linea: 679904
# linea: 679905
# linea: 679906
# linea: 679907
# linea: 679908
# linea: 679909
# linea: 679910
# linea: 679911
# linea: 679912
# linea: 679913
# linea: 679914
# linea: 679915
# linea: 679916
# linea: 679917
# linea: 679918
# linea: 679919
# linea: 679920
# linea: 679921
# linea: 679922
# linea: 679923
# linea: 679924
# linea: 679925
# linea: 679926
# linea: 679927
# linea: 679928
# linea: 679929
# linea: 679930
# linea: 679931
# linea: 679932
# linea: 679933
# linea: 679934
# linea: 679935
# linea: 679936
# linea: 679937
# linea: 679938
# linea: 679939
# linea: 679940
# linea: 679941
# linea: 679942
# linea: 679943
# linea: 679944
# linea: 679945
# linea: 679946
# linea: 679947
# linea: 679948
# linea: 679949
# linea: 679950
# linea: 679951
# linea: 679952
# linea: 679953
# linea: 679954
# linea: 679955
# linea: 679956
# linea: 679957
# linea: 679958
# linea: 679959
# linea: 679960
# linea: 679961
# linea: 679962
# linea: 679963
# linea: 679964
# linea: 679965
# linea: 679966
# linea: 679967
# linea: 679968
# linea: 679969
# linea: 679970
# linea: 679971
# linea: 679972
# linea: 679973
# linea: 679974
# linea: 679975
# linea: 679976
# linea: 679977
# linea: 679978
# linea: 679979
# linea: 679980
# linea: 679981
# linea: 679982
# linea: 679983
# linea: 679984
# linea: 679985
# linea: 679986
# linea: 679987
# linea: 679988
# linea: 679989
# linea: 679990
# linea: 679991
# linea: 679992
# linea: 679993
# linea: 679994
# linea: 679995
# linea: 679996
# linea: 679997
# linea: 679998
# linea: 679999
# linea: 680000
# linea: 680001
# linea: 680002
# linea: 680003
# linea: 680004
# linea: 680005
# linea: 680006
# linea: 680007
# linea: 680008
# linea: 680009
# linea: 680010
# linea: 680011
# linea: 680012
# linea: 680013
# linea: 680014
# linea: 680015
# linea: 680016
# linea: 680017
# linea: 680018
# linea: 680019
# linea: 680020
# linea: 680021
# linea: 680022
# linea: 680023
# linea: 680024
# linea: 680025
# linea: 680026
# linea: 680027
# linea: 680028
# linea: 680029
# linea: 680030
# linea: 680031
# linea: 680032
# linea: 680033
# linea: 680034
# linea: 680035
# linea: 680036
# linea: 680037
# linea: 680038
# linea: 680039
# linea: 680040
# linea: 680041
# linea: 680042
# linea: 680043
# linea: 680044
# linea: 680045
# linea: 680046
# linea: 680047
# linea: 680048
# linea: 680049
# linea: 680050
# linea: 680051
# linea: 680052
# linea: 680053
# linea: 680054
# linea: 680055
# linea: 680056
# linea: 680057
# linea: 680058
# linea: 680059
# linea: 680060
# linea: 680061
# linea: 680062
# linea: 680063
# linea: 680064
# linea: 680065
# linea: 680066
# linea: 680067
# linea: 680068
# linea: 680069
# linea: 680070
# linea: 680071
# linea: 680072
# linea: 680073
# linea: 680074
# linea: 680075
# linea: 680076
# linea: 680077
# linea: 680078
# linea: 680079
# linea: 680080
# linea: 680081
# linea: 680082
# linea: 680083
# linea: 680084
# linea: 680085
# linea: 680086
# linea: 680087
# linea: 680088
# linea: 680089
# linea: 680090
# linea: 680091
# linea: 680092
# linea: 680093
# linea: 680094
# linea: 680095
# linea: 680096
# linea: 680097
# linea: 680098
# linea: 680099
# linea: 680100
# linea: 680101
# linea: 680102
# linea: 680103
# linea: 680104
# linea: 680105
# linea: 680106
# linea: 680107
# linea: 680108
# linea: 680109
# linea: 680110
# linea: 680111
# linea: 680112
# linea: 680113
# linea: 680114
# linea: 680115
# linea: 680116
# linea: 680117
# linea: 680118
# linea: 680119
# linea: 680120
# linea: 680121
# linea: 680122
# linea: 680123
# linea: 680124
# linea: 680125
# linea: 680126
# linea: 680127
# linea: 680128
# linea: 680129
# linea: 680130
# linea: 680131
# linea: 680132
# linea: 680133
# linea: 680134
# linea: 680135
# linea: 680136
# linea: 680137
# linea: 680138
# linea: 680139
# linea: 680140
# linea: 680141
# linea: 680142
# linea: 680143
# linea: 680144
# linea: 680145
# linea: 680146
# linea: 680147
# linea: 680148
# linea: 680149
# linea: 680150
# linea: 680151
# linea: 680152
# linea: 680153
# linea: 680154
# linea: 680155
# linea: 680156
# linea: 680157
# linea: 680158
# linea: 680159
# linea: 680160
# linea: 680161
# linea: 680162
# linea: 680163
# linea: 680164
# linea: 680165
# linea: 680166
# linea: 680167
# linea: 680168
# linea: 680169
# linea: 680170
# linea: 680171
# linea: 680172
# linea: 680173
# linea: 680174
# linea: 680175
# linea: 680176
# linea: 680177
# linea: 680178
# linea: 680179
# linea: 680180
# linea: 680181
# linea: 680182
# linea: 680183
# linea: 680184
# linea: 680185
# linea: 680186
# linea: 680187
# linea: 680188
# linea: 680189
# linea: 680190
# linea: 680191
# linea: 680192
# linea: 680193
# linea: 680194
# linea: 680195
# linea: 680196
# linea: 680197
# linea: 680198
# linea: 680199
# linea: 680200
# linea: 680201
# linea: 680202
# linea: 680203
# linea: 680204
# linea: 680205
# linea: 680206
# linea: 680207
# linea: 680208
# linea: 680209
# linea: 680210
# linea: 680211
# linea: 680212
# linea: 680213
# linea: 680214
# linea: 680215
# linea: 680216
# linea: 680217
# linea: 680218
# linea: 680219
# linea: 680220
# linea: 680221
# linea: 680222
# linea: 680223
# linea: 680224
# linea: 680225
# linea: 680226
# linea: 680227
# linea: 680228
# linea: 680229
# linea: 680230
# linea: 680231
# linea: 680232
# linea: 680233
# linea: 680234
# linea: 680235
# linea: 680236
# linea: 680237
# linea: 680238
# linea: 680239
# linea: 680240
# linea: 680241
# linea: 680242
# linea: 680243
# linea: 680244
# linea: 680245
# linea: 680246
# linea: 680247
# linea: 680248
# linea: 680249
# linea: 680250
# linea: 680251
# linea: 680252
# linea: 680253
# linea: 680254
# linea: 680255
# linea: 680256
# linea: 680257
# linea: 680258
# linea: 680259
# linea: 680260
# linea: 680261
# linea: 680262
# linea: 680263
# linea: 680264
# linea: 680265
# linea: 680266
# linea: 680267
# linea: 680268
# linea: 680269
# linea: 680270
# linea: 680271
# linea: 680272
# linea: 680273
# linea: 680274
# linea: 680275
# linea: 680276
# linea: 680277
# linea: 680278
# linea: 680279
# linea: 680280
# linea: 680281
# linea: 680282
# linea: 680283
# linea: 680284
# linea: 680285
# linea: 680286
# linea: 680287
# linea: 680288
# linea: 680289
# linea: 680290
# linea: 680291
# linea: 680292
# linea: 680293
# linea: 680294
# linea: 680295
# linea: 680296
# linea: 680297
# linea: 680298
# linea: 680299
# linea: 680300
# linea: 680301
# linea: 680302
# linea: 680303
# linea: 680304
# linea: 680305
# linea: 680306
# linea: 680307
# linea: 680308
# linea: 680309
# linea: 680310
# linea: 680311
# linea: 680312
# linea: 680313
# linea: 680314
# linea: 680315
# linea: 680316
# linea: 680317
# linea: 680318
# linea: 680319
# linea: 680320
# linea: 680321
# linea: 680322
# linea: 680323
# linea: 680324
# linea: 680325
# linea: 680326
# linea: 680327
# linea: 680328
# linea: 680329
# linea: 680330
# linea: 680331
# linea: 680332
# linea: 680333
# linea: 680334
# linea: 680335
# linea: 680336
# linea: 680337
# linea: 680338
# linea: 680339
# linea: 680340
# linea: 680341
# linea: 680342
# linea: 680343
# linea: 680344
# linea: 680345
# linea: 680346
# linea: 680347
# linea: 680348
# linea: 680349
# linea: 680350
# linea: 680351
# linea: 680352
# linea: 680353
# linea: 680354
# linea: 680355
# linea: 680356
# linea: 680357
# linea: 680358
# linea: 680359
# linea: 680360
# linea: 680361
# linea: 680362
# linea: 680363
# linea: 680364
# linea: 680365
# linea: 680366
# linea: 680367
# linea: 680368
# linea: 680369
# linea: 680370
# linea: 680371
# linea: 680372
# linea: 680373
# linea: 680374
# linea: 680375
# linea: 680376
# linea: 680377
# linea: 680378
# linea: 680379
# linea: 680380
# linea: 680381
# linea: 680382
# linea: 680383
# linea: 680384
# linea: 680385
# linea: 680386
# linea: 680387
# linea: 680388
# linea: 680389
# linea: 680390
# linea: 680391
# linea: 680392
# linea: 680393
# linea: 680394
# linea: 680395
# linea: 680396
# linea: 680397
# linea: 680398
# linea: 680399
# linea: 680400
# linea: 680401
# linea: 680402
# linea: 680403
# linea: 680404
# linea: 680405
# linea: 680406
# linea: 680407
# linea: 680408
# linea: 680409
# linea: 680410
# linea: 680411
# linea: 680412
# linea: 680413
# linea: 680414
# linea: 680415
# linea: 680416
# linea: 680417
# linea: 680418
# linea: 680419
# linea: 680420
# linea: 680421
# linea: 680422
# linea: 680423
# linea: 680424
# linea: 680425
# linea: 680426
# linea: 680427
# linea: 680428
# linea: 680429
# linea: 680430
# linea: 680431
# linea: 680432
# linea: 680433
# linea: 680434
# linea: 680435
# linea: 680436
# linea: 680437
# linea: 680438
# linea: 680439
# linea: 680440
# linea: 680441
# linea: 680442
# linea: 680443
# linea: 680444
# linea: 680445
# linea: 680446
# linea: 680447
# linea: 680448
# linea: 680449
# linea: 680450
# linea: 680451
# linea: 680452
# linea: 680453
# linea: 680454
# linea: 680455
# linea: 680456
# linea: 680457
# linea: 680458
# linea: 680459
# linea: 680460
# linea: 680461
# linea: 680462
# linea: 680463
# linea: 680464
# linea: 680465
# linea: 680466
# linea: 680467
# linea: 680468
# linea: 680469
# linea: 680470
# linea: 680471
# linea: 680472
# linea: 680473
# linea: 680474
# linea: 680475
# linea: 680476
# linea: 680477
# linea: 680478
# linea: 680479
# linea: 680480
# linea: 680481
# linea: 680482
# linea: 680483
# linea: 680484
# linea: 680485
# linea: 680486
# linea: 680487
# linea: 680488
# linea: 680489
# linea: 680490
# linea: 680491
# linea: 680492
# linea: 680493
# linea: 680494
# linea: 680495
# linea: 680496
# linea: 680497
# linea: 680498
# linea: 680499
# linea: 680500
# linea: 680501
# linea: 680502
# linea: 680503
# linea: 680504
# linea: 680505
# linea: 680506
# linea: 680507
# linea: 680508
# linea: 680509
# linea: 680510
# linea: 680511
# linea: 680512
# linea: 680513
# linea: 680514
# linea: 680515
# linea: 680516
# linea: 680517
# linea: 680518
# linea: 680519
# linea: 680520
# linea: 680521
# linea: 680522
# linea: 680523
# linea: 680524
# linea: 680525
# linea: 680526
# linea: 680527
# linea: 680528
# linea: 680529
# linea: 680530
# linea: 680531
# linea: 680532
# linea: 680533
# linea: 680534
# linea: 680535
# linea: 680536
# linea: 680537
# linea: 680538
# linea: 680539
# linea: 680540
# linea: 680541
# linea: 680542
# linea: 680543
# linea: 680544
# linea: 680545
# linea: 680546
# linea: 680547
# linea: 680548
# linea: 680549
# linea: 680550
# linea: 680551
# linea: 680552
# linea: 680553
# linea: 680554
# linea: 680555
# linea: 680556
# linea: 680557
# linea: 680558
# linea: 680559
# linea: 680560
# linea: 680561
# linea: 680562
# linea: 680563
# linea: 680564
# linea: 680565
# linea: 680566
# linea: 680567
# linea: 680568
# linea: 680569
# linea: 680570
# linea: 680571
# linea: 680572
# linea: 680573
# linea: 680574
# linea: 680575
# linea: 680576
# linea: 680577
# linea: 680578
# linea: 680579
# linea: 680580
# linea: 680581
# linea: 680582
# linea: 680583
# linea: 680584
# linea: 680585
# linea: 680586
# linea: 680587
# linea: 680588
# linea: 680589
# linea: 680590
# linea: 680591
# linea: 680592
# linea: 680593
# linea: 680594
# linea: 680595
# linea: 680596
# linea: 680597
# linea: 680598
# linea: 680599
# linea: 680600
# linea: 680601
# linea: 680602
# linea: 680603
# linea: 680604
# linea: 680605
# linea: 680606
# linea: 680607
# linea: 680608
# linea: 680609
# linea: 680610
# linea: 680611
# linea: 680612
# linea: 680613
# linea: 680614
# linea: 680615
# linea: 680616
# linea: 680617
# linea: 680618
# linea: 680619
# linea: 680620
# linea: 680621
# linea: 680622
# linea: 680623
# linea: 680624
# linea: 680625
# linea: 680626
# linea: 680627
# linea: 680628
# linea: 680629
# linea: 680630
# linea: 680631
# linea: 680632
# linea: 680633
# linea: 680634
# linea: 680635
# linea: 680636
# linea: 680637
# linea: 680638
# linea: 680639
# linea: 680640
# linea: 680641
# linea: 680642
# linea: 680643
# linea: 680644
# linea: 680645
# linea: 680646
# linea: 680647
# linea: 680648
# linea: 680649
# linea: 680650
# linea: 680651
# linea: 680652
# linea: 680653
# linea: 680654
# linea: 680655
# linea: 680656
# linea: 680657
# linea: 680658
# linea: 680659
# linea: 680660
# linea: 680661
# linea: 680662
# linea: 680663
# linea: 680664
# linea: 680665
# linea: 680666
# linea: 680667
# linea: 680668
# linea: 680669
# linea: 680670
# linea: 680671
# linea: 680672
# linea: 680673
# linea: 680674
# linea: 680675
# linea: 680676
# linea: 680677
# linea: 680678
# linea: 680679
# linea: 680680
# linea: 680681
# linea: 680682
# linea: 680683
# linea: 680684
# linea: 680685
# linea: 680686
# linea: 680687
# linea: 680688
# linea: 680689
# linea: 680690
# linea: 680691
# linea: 680692
# linea: 680693
# linea: 680694
# linea: 680695
# linea: 680696
# linea: 680697
# linea: 680698
# linea: 680699
# linea: 680700
# linea: 680701
# linea: 680702
# linea: 680703
# linea: 680704
# linea: 680705
# linea: 680706
# linea: 680707
# linea: 680708
# linea: 680709
# linea: 680710
# linea: 680711
# linea: 680712
# linea: 680713
# linea: 680714
# linea: 680715
# linea: 680716
# linea: 680717
# linea: 680718
# linea: 680719
# linea: 680720
# linea: 680721
# linea: 680722
# linea: 680723
# linea: 680724
# linea: 680725
# linea: 680726
# linea: 680727
# linea: 680728
# linea: 680729
# linea: 680730
# linea: 680731
# linea: 680732
# linea: 680733
# linea: 680734
# linea: 680735
# linea: 680736
# linea: 680737
# linea: 680738
# linea: 680739
# linea: 680740
# linea: 680741
# linea: 680742
# linea: 680743
# linea: 680744
# linea: 680745
# linea: 680746
# linea: 680747
# linea: 680748
# linea: 680749
# linea: 680750
# linea: 680751
# linea: 680752
# linea: 680753
# linea: 680754
# linea: 680755
# linea: 680756
# linea: 680757
# linea: 680758
# linea: 680759
# linea: 680760
# linea: 680761
# linea: 680762
# linea: 680763
# linea: 680764
# linea: 680765
# linea: 680766
# linea: 680767
# linea: 680768
# linea: 680769
# linea: 680770
# linea: 680771
# linea: 680772
# linea: 680773
# linea: 680774
# linea: 680775
# linea: 680776
# linea: 680777
# linea: 680778
# linea: 680779
# linea: 680780
# linea: 680781
# linea: 680782
# linea: 680783
# linea: 680784
# linea: 680785
# linea: 680786
# linea: 680787
# linea: 680788
# linea: 680789
# linea: 680790
# linea: 680791
# linea: 680792
# linea: 680793
# linea: 680794
# linea: 680795
# linea: 680796
# linea: 680797
# linea: 680798
# linea: 680799
# linea: 680800
# linea: 680801
# linea: 680802
# linea: 680803
# linea: 680804
# linea: 680805
# linea: 680806
# linea: 680807
# linea: 680808
# linea: 680809
# linea: 680810
# linea: 680811
# linea: 680812
# linea: 680813
# linea: 680814
# linea: 680815
# linea: 680816
# linea: 680817
# linea: 680818
# linea: 680819
# linea: 680820
# linea: 680821
# linea: 680822
# linea: 680823
# linea: 680824
# linea: 680825
# linea: 680826
# linea: 680827
# linea: 680828
# linea: 680829
# linea: 680830
# linea: 680831
# linea: 680832
# linea: 680833
# linea: 680834
# linea: 680835
# linea: 680836
# linea: 680837
# linea: 680838
# linea: 680839
# linea: 680840
# linea: 680841
# linea: 680842
# linea: 680843
# linea: 680844
# linea: 680845
# linea: 680846
# linea: 680847
# linea: 680848
# linea: 680849
# linea: 680850
# linea: 680851
# linea: 680852
# linea: 680853
# linea: 680854
# linea: 680855
# linea: 680856
# linea: 680857
# linea: 680858
# linea: 680859
# linea: 680860
# linea: 680861
# linea: 680862
# linea: 680863
# linea: 680864
# linea: 680865
# linea: 680866
# linea: 680867
# linea: 680868
# linea: 680869
# linea: 680870
# linea: 680871
# linea: 680872
# linea: 680873
# linea: 680874
# linea: 680875
# linea: 680876
# linea: 680877
# linea: 680878
# linea: 680879
# linea: 680880
# linea: 680881
# linea: 680882
# linea: 680883
# linea: 680884
# linea: 680885
# linea: 680886
# Empty DataFrame
# Columns: [λ(nm), f, Assignment, MOs Transition, cts (%)]
# Index: []
# |--------------- PROCESO TERMINADO ----------------|
# CPU times: user 1min 57s, sys: 9.4 s, total: 2min 6s
# Wall time: 2min 6s
# Parser   : 216 ms

# %%
with open("output.txt", "w", encoding="utf-8") as file:
    file.write(captured_output.stdout)
print("listo")
# Out:
# listo
